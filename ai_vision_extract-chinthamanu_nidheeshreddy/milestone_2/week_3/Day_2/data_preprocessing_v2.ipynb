# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pycocotools.coco import COCO # Common Object in Context
import numpy as np
import cv2
import os
from tqdm import tqdm

# base path
base_path = r'/content/drive/MyDrive/AI_Vision_Extract_Nov25/data/COCO2017_SAMPLE'

# Create output directory with FULL PATH
masks_output_dir = os.path.join(base_path, 'mask_val2017')
os.makedirs(masks_output_dir, exist_ok=True)

print(f"Saving masks to: {masks_output_dir}")

# Load val annotations
annotations_path = os.path.join(base_path, '/content/drive/MyDrive/AI_Vision_Extract_Nov25/data/annotations/captions_train2017.json')
coco = COCO(annotations_path)
img_ids = coco.getImgIds()

print(f"Total val images: {len(img_ids)}")

# Create masks for val images
for img_id in tqdm(img_ids, desc='Creating val masks'):
   try:
     img_info = coco.loadImgs(img_id)[0]
     ann_ids = coco.getAnnIds(imgIds=img_id)
     anns = coco.loadAnns(ann_ids)

     # Create binary mask
     mask = np.zeros((img_info['height'], img_info['width']), dtype = np.uint8)

     for ann in  anns:
        mask += coco.annToMask(ann)
     # Binary conversion (0 or 255)
     mask = (mask > 0).astype(np.uint8) * 255

     # Save with matching filename using ABSOLUTE PATH
     mask_filename = img_info(['file_name']).replace('.jpg', '_mask.png')
     mask_path = os.path.join(masks_output_dir, mask_filename)
     cv2.inwrite(mask_path, mask)
   except Exception as e:
     print(f"Error processing image {img_id}: {str(e)}")

print("✓ Training masks created successfully!")

# Verify masks were created
mask_count = len(os.listdir(masks_output_dir))
print(f"✓ Verified: {mask_count} mask files created in {masks_output_dir}")
# Out:
# Saving masks to: /content/drive/MyDrive/AI_Vision_Extract_Nov25/data/COCO2017_SAMPLE/mask_val2017
# loading annotations into memory...
# Done (t=3.89s)
# creating index...
# index created!
# Total val images: 118287
# Creating val masks:   4%|▍         | 4840/118287 [00:00<00:02, 48393.47it/s]
# Streaming output truncated to the last 5000 lines.
# Error processing image 187177: 'segmentation'
# Error processing image 403349: 'segmentation'
# Error processing image 124873: 'segmentation'
# Error processing image 468162: 'segmentation'
# Error processing image 34892: 'segmentation'
# Error processing image 544071: 'segmentation'
# Error processing image 12966: 'segmentation'
# Error processing image 357356: 'segmentation'
# Error processing image 142940: 'segmentation'
# Error processing image 548331: 'segmentation'
# Error processing image 462241: 'segmentation'
# Error processing image 442565: 'segmentation'
# Error processing image 78838: 'segmentation'
# Error processing image 91474: 'segmentation'
# Error processing image 200720: 'segmentation'
# Error processing image 430652: 'segmentation'
# Error processing image 569070: 'segmentation'
# Error processing image 344314: 'segmentation'
# Error processing image 243331: 'segmentation'
# Error processing image 440895: 'segmentation'
# Error processing image 130791: 'segmentation'
# Error processing image 10077: 'segmentation'
# Error processing image 43165: 'segmentation'
# Error processing image 451305: 'segmentation'
# Error processing image 293591: 'segmentation'
# Error processing image 46975: 'segmentation'
# Error processing image 544639: 'segmentation'
# Error processing image 150040: 'segmentation'
# Error processing image 272961: 'segmentation'
# Error processing image 113579: 'segmentation'
# Error processing image 318146: 'segmentation'
# Error processing image 383293: 'segmentation'
# Error processing image 431521: 'segmentation'
# Error processing image 565431: 'segmentation'
# Error processing image 383229: 'segmentation'
# Error processing image 570695: 'segmentation'
# Error processing image 137085: 'segmentation'
# Error processing image 21397: 'segmentation'
# Error processing image 226744: 'segmentation'
# Error processing image 424174: 'segmentation'
# Error processing image 572571: 'segmentation'
# Error processing image 72275: 'segmentation'
# Error processing image 577073: 'segmentation'
# Error processing image 479129: 'segmentation'
# Error processing image 13031: 'segmentation'
# Error processing image 332096: 'segmentation'
# Error processing image 402922: 'segmentation'
# Error processing image 350463: 'segmentation'
# Error processing image 158722: 'segmentation'
# Error processing image 35368: 'segmentation'
# Error processing image 394801: 'segmentation'
# Error processing image 498439: 'segmentation'
# Error processing image 523560: 'segmentation'
# Error processing image 240259: 'segmentation'
# Error processing image 419789: 'segmentation'
# Error processing image 373577: 'segmentation'
# Error processing image 387824: 'segmentation'
# Error processing image 420330: 'segmentation'
# Error processing image 390215: 'segmentation'
# Error processing image 239808: 'segmentation'
# Error processing image 226170: 'segmentation'
# Error processing image 391320: 'segmentation'
# Error processing image 76956: 'segmentation'
# Error processing image 352214: 'segmentation'
# Error processing image 398563: 'segmentation'
# Error processing image 464087: 'segmentation'
# Error processing image 55074: 'segmentation'
# Error processing image 443169: 'segmentation'
# Error processing image 156687: 'segmentation'
# Error processing image 49740: 'segmentation'
# Error processing image 492323: 'segmentation'
# Error processing image 308630: 'segmentation'
# Error processing image 313176: 'segmentation'
# Error processing image 556726: 'segmentation'
# Error processing image 149284: 'segmentation'
# Error processing image 311385: 'segmentation'
# Error processing image 231052: 'segmentation'
# Error processing image 26512: 'segmentation'
# Error processing image 286313: 'segmentation'
# Error processing image 549462: 'segmentation'
# Error processing image 94666: 'segmentation'
# Error processing image 67075: 'segmentation'
# Error processing image 579201: 'segmentation'
# Error processing image 431370: 'segmentation'
# Error processing image 548939: 'segmentation'
# Error processing image 307683: 'segmentation'
# Error processing image 474034: 'segmentation'
# Error processing image 294605: 'segmentation'
# Error processing image 284681: 'segmentation'
# Error processing image 205911: 'segmentation'
# Error processing image 365983: 'segmentation'
# Error processing image 423498: 'segmentation'
# Error processing image 362103: 'segmentation'
# Error processing image 108243: 'segmentation'
# Error processing image 539079: 'segmentation'
# Error processing image 274835: 'segmentation'
# Error processing image 364187: 'segmentation'
# Error processing image 530619: 'segmentation'
# Error processing image 452931: 'segmentation'
# Error processing image 251531: 'segmentation'
# Error processing image 223587: 'segmentation'
# Error processing image 493206: 'segmentation'
# Error processing image 352418: 'segmentation'
# Error processing image 238708: 'segmentation'
# Error processing image 36238: 'segmentation'
# Error processing image 73668: 'segmentation'
# Error processing image 363358: 'segmentation'
# Error processing image 274549: 'segmentation'
# Error processing image 520508: 'segmentation'
# Error processing image 297078: 'segmentation'
# Error processing image 220277: 'segmentation'
# Error processing image 419503: 'segmentation'
# Error processing image 500110: 'segmentation'
# Error processing image 149456: 'segmentation'
# Error processing image 452676: 'segmentation'
# Error processing image 223327: 'segmentation'
# Error processing image 398153: 'segmentation'
# Error processing image 558234: 'segmentation'
# Error processing image 247999: 'segmentation'
# Error processing image 30049: 'segmentation'
# Error processing image 217654: 'segmentation'
# Error processing image 404528: 'segmentation'
# Error processing image 107020: 'segmentation'
# Error processing image 390731: 'segmentation'
# Error processing image 105053: 'segmentation'
# Error processing image 143387: 'segmentation'
# Error processing image 573571: 'segmentation'
# Error processing image 218889: 'segmentation'
# Error processing image 129595: 'segmentation'
# Error processing image 440840: 'segmentation'
# Error processing image 142934: 'segmentation'
# Error processing image 209357: 'segmentation'
# Error processing image 131800: 'segmentation'
# Error processing image 57172: 'segmentation'
# Error processing image 214853: 'segmentation'
# Error processing image 151299: 'segmentation'
# Error processing image 497907: 'segmentation'
# Error processing image 436696: 'segmentation'
# Error processing image 146272: 'segmentation'
# Error processing image 357808: 'segmentation'
# Error processing image 218721: 'segmentation'
# Error processing image 362506: 'segmentation'
# Error processing image 117014: 'segmentation'
# Error processing image 74349: 'segmentation'
# Error processing image 473774: 'segmentation'
# Error processing image 42953: 'segmentation'
# Error processing image 190391: 'segmentation'
# Error processing image 283162: 'segmentation'
# Error processing image 208690: 'segmentation'
# Error processing image 256743: 'segmentation'
# Error processing image 554340: 'segmentation'
# Error processing image 387208: 'segmentation'
# Error processing image 151826: 'segmentation'
# Error processing image 537211: 'segmentation'
# Error processing image 341246: 'segmentation'
# Error processing image 301766: 'segmentation'
# Error processing image 120398: 'segmentation'
# Error processing image 409627: 'segmentation'
# Error processing image 16744: 'segmentation'
# Error processing image 183786: 'segmentation'
# Error processing image 139953: 'segmentation'
# Error processing image 51920: 'segmentation'
# Error processing image 434930: 'segmentation'
# Error processing image 38323: 'segmentation'
# Error processing image 204609: 'segmentation'
# Error processing image 368049: 'segmentation'
# Error processing image 491062: 'segmentation'
# Error processing image 263073: 'segmentation'
# Error processing image 224020: 'segmentation'
# Error processing image 445557: 'segmentation'
# Error processing image 122232: 'segmentation'
# Error processing image 523097: 'segmentation'
# Error processing image 437099: 'segmentation'
# Error processing image 330237: 'segmentation'
# Error processing image 336487: 'segmentation'
# Error processing image 270544: 'segmentation'
# Error processing image 325027: 'segmentation'
# Error processing image 95249: 'segmentation'
# Error processing image 560662: 'segmentation'
# Error processing image 62230: 'segmentation'
# Error processing image 39858: 'segmentation'
# Error processing image 131593: 'segmentation'
# Error processing image 139518: 'segmentation'
# Error processing image 233961: 'segmentation'
# Error processing image 227599: 'segmentation'
# Error processing image 103161: 'segmentation'
# Error processing image 418440: 'segmentation'
# Error processing image 501858: 'segmentation'
# Error processing image 456969: 'segmentation'
# Error processing image 495156: 'segmentation'
# Error processing image 71385: 'segmentation'
# Error processing image 36420: 'segmentation'
# Error processing image 161622: 'segmentation'
# Error processing image 410885: 'segmentation'
# Error processing image 336872: 'segmentation'
# Error processing image 810: 'segmentation'
# Error processing image 451008: 'segmentation'
# Error processing image 541926: 'segmentation'
# Error processing image 8191: 'segmentation'
# Error processing image 347515: 'segmentation'
# Error processing image 22199: 'segmentation'
# Error processing image 469338: 'segmentation'
# Error processing image 163436: 'segmentation'
# Error processing image 465878: 'segmentation'
# Error processing image 560757: 'segmentation'
# Error processing image 62363: 'segmentation'
# Error processing image 301305: 'segmentation'
# Error processing image 507951: 'segmentation'
# Error processing image 226579: 'segmentation'
# Error processing image 456261: 'segmentation'
# Error processing image 566529: 'segmentation'
# Error processing image 468022: 'segmentation'
# Error processing image 405188: 'segmentation'
# Error processing image 384089: 'segmentation'
# Error processing image 473850: 'segmentation'
# Error processing image 176381: 'segmentation'
# Error processing image 379488: 'segmentation'
# Error processing image 185335: 'segmentation'
# Error processing image 312524: 'segmentation'
# Error processing image 546029: 'segmentation'
# Error processing image 237420: 'segmentation'
# Error processing image 341111: 'segmentation'
# Error processing image 371497: 'segmentation'
# Error processing image 375285: 'segmentation'
# Error processing image 484842: 'segmentation'
# Error processing image 277422: 'segmentation'
# Error processing image 403078: 'segmentation'
# Error processing image 559380: 'segmentation'
# Error processing image 503332: 'segmentation'
# Error processing image 568154: 'segmentation'
# Error processing image 544334: 'segmentation'
# Error processing image 455633: 'segmentation'
# Error processing image 173083: 'segmentation'
# Error processing image 253518: 'segmentation'
# Error processing image 208377: 'segmentation'
# Error processing image 481035: 'segmentation'
# Error processing image 105234: 'segmentation'
# Error processing image 468171: 'segmentation'
# Error processing image 318063: 'segmentation'
# Error processing image 31971: 'segmentation'
# Error processing image 485294: 'segmentation'
# Error processing image 497826: 'segmentation'
# Error processing image 203734: 'segmentation'
# Error processing image 139486: 'segmentation'
# Error processing image 128570: 'segmentation'
# Error processing image 439770: 'segmentation'
# Error processing image 315991: 'segmentation'
# Error processing image 279331: 'segmentation'
# Error processing image 355168: 'segmentation'
# Error processing image 93730: 'segmentation'
# Error processing image 8688: 'segmentation'
# Error processing image 164983: 'segmentation'
# Error processing image 125435: 'segmentation'
# Error processing image 121632: 'segmentation'
# Error processing image 177990: 'segmentation'
# Error processing image 526972: 'segmentation'
# Error processing image 164453: 'segmentation'
# Error processing image 411303: 'segmentation'
# Error processing image 124911: 'segmentation'
# Error processing image 534161: 'segmentation'
# Error processing image 60992: 'segmentation'
# Error processing image 470350: 'segmentation'
# Error processing image 487630: 'segmentation'
# Error processing image 126229: 'segmentation'
# Error processing image 67966: 'segmentation'
# Error processing image 541351: 'segmentation'
# Error processing image 355424: 'segmentation'
# Error processing image 478528: 'segmentation'
# Error processing image 229207: 'segmentation'
# Error processing image 409784: 'segmentation'
# Error processing image 462845: 'segmentation'
# Error processing image 412798: 'segmentation'
# Error processing image 322937: 'segmentation'
# Error processing image 219737: 'segmentation'
# Error processing image 543409: 'segmentation'
# Error processing image 574154: 'segmentation'
# Error processing image 37158: 'segmentation'
# Error processing image 10123: 'segmentation'
# Error processing image 482829: 'segmentation'
# Error processing image 4312: 'segmentation'
# Error processing image 408906: 'segmentation'
# Error processing image 449567: 'segmentation'
# Error processing image 255627: 'segmentation'
# Error processing image 437732: 'segmentation'
# Error processing image 540159: 'segmentation'
# Error processing image 57403: 'segmentation'
# Error processing image 291115: 'segmentation'
# Error processing image 508872: 'segmentation'
# Error processing image 52312: 'segmentation'
# Error processing image 540473: 'segmentation'
# Error processing image 27805: 'segmentation'
# Error processing image 410101: 'segmentation'
# Error processing image 308156: 'segmentation'
# Error processing image 531852: 'segmentation'
# Error processing image 512223: 'segmentation'
# Error processing image 473210: 'segmentation'
# Error processing image 415163: 'segmentation'
# Error processing image 353969: 'segmentation'
# Error processing image 82150: 'segmentation'
# Error processing image 325351: 'segmentation'
# Error processing image 217546: 'segmentation'
# Error processing image 309104: 'segmentation'
# Error processing image 514787: 'segmentation'
# Error processing image 549109: 'segmentation'
# Error processing image 26584: 'segmentation'
# Error processing image 416304: 'segmentation'
# Error processing image 570188: 'segmentation'
# Error processing image 167610: 'segmentation'
# Error processing image 353347: 'segmentation'
# Error processing image 60569: 'segmentation'
# Error processing image 552832: 'segmentation'
# Error processing image 351345: 'segmentation'
# Error processing image 155546: 'segmentation'
# Error processing image 481518: 'segmentation'
# Error processing image 533743: 'segmentation'
# Error processing image 164759: 'segmentation'
# Error processing image 277984: 'segmentation'
# Error processing image 463290: 'segmentation'
# Error processing image 361527: 'segmentation'
# Error processing image 296255: 'segmentation'
# Error processing image 243158: 'segmentation'
# Error processing image 96539: 'segmentation'
# Error processing image 553471: 'segmentation'
# Error processing image 371036: 'segmentation'
# Error processing image 482236: 'segmentation'
# Error processing image 298933: 'segmentation'
# Error processing image 233848: 'segmentation'
# Error processing image 475917: 'segmentation'
# Error processing image 398450: 'segmentation'
# Error processing image 26432: 'segmentation'
# Error processing image 281782: 'segmentation'
# Error processing image 487612: 'segmentation'
# Error processing image 33061: 'segmentation'
# Error processing image 241102: 'segmentation'
# Error processing image 39322: 'segmentation'
# Error processing image 412587: 'segmentation'
# Error processing image 421865: 'segmentation'
# Error processing image 257838: 'segmentation'
# Error processing image 499093: 'segmentation'
# Error processing image 291962: 'segmentation'
# Error processing image 147904: 'segmentation'
# Error processing image 162445: 'segmentation'
# Error processing image 525666: 'segmentation'
# Error processing image 492524: 'segmentation'
# Error processing image 531149: 'segmentation'
# Error processing image 470909: 'segmentation'
# Error processing image 157109: 'segmentation'
# Error processing image 551518: 'segmentation'
# Error processing image 294182: 'segmentation'
# Error processing image 242208: 'segmentation'
# Error processing image 192806: 'segmentation'
# Error processing image 464274: 'segmentation'
# Error processing image 303024: 'segmentation'
# Error processing image 432239: 'segmentation'
# Error processing image 2529: 'segmentation'
# Error processing image 506628: 'segmentation'
# Error processing image 136642: 'segmentation'
# Error processing image 526800: 'segmentation'
# Error processing image 249184: 'segmentation'
# Error processing image 322848: 'segmentation'
# Error processing image 138553: 'segmentation'
# Error processing image 281688: 'segmentation'
# Error processing image 231281: 'segmentation'
# Error processing image 575051: 'segmentation'
# Error processing image 386819: 'segmentation'
# Error processing image 105973: 'segmentation'
# Error processing image 99219: 'segmentation'
# Error processing image 12209: 'segmentation'
# Error processing image 455005: 'segmentation'
# Error processing image 378970: 'segmentation'
# Error processing image 8065: 'segmentation'
# Error processing image 266376: 'segmentation'
# Error processing image 462931: 'segmentation'
# Error processing image 5385: 'segmentation'
# Error processing image 101860: 'segmentation'
# Error processing image 561745: 'segmentation'
# Error processing image 87393: 'segmentation'
# Error processing image 410328: 'segmentation'
# Error processing image 111244: 'segmentation'
# Error processing image 364073: 'segmentation'
# Error processing image 142742: 'segmentation'
# Error processing image 368576: 'segmentation'
# Error processing image 128142: 'segmentation'
# Error processing image 520787: 'segmentation'
# Error processing image 574095: 'segmentation'
# Error processing image 251920: 'segmentation'
# Error processing image 525646: 'segmentation'
# Error processing image 361351: 'segmentation'
# Error processing image 425805: 'segmentation'
# Error processing image 169885: 'segmentation'
# Error processing image 207886: 'segmentation'
# Error processing image 118739: 'segmentation'
# Error processing image 225565: 'segmentation'
# Error processing image 485236: 'segmentation'
# Error processing image 383073: 'segmentation'
# Error processing image 485288: 'segmentation'
# Error processing image 280560: 'segmentation'
# Error processing image 271117: 'segmentation'
# Error processing image 288874: 'segmentation'
# Error processing image 281882: 'segmentation'
# Error processing image 190898: 'segmentation'
# Error processing image 233528: 'segmentation'
# Error processing image 1436: 'segmentation'
# Error processing image 385641: 'segmentation'
# Error processing image 506515: 'segmentation'
# Error processing image 246001: 'segmentation'
# Error processing image 347390: 'segmentation'
# Error processing image 485580: 'segmentation'
# Error processing image 226412: 'segmentation'
# Error processing image 441293: 'segmentation'
# Error processing image 258734: 'segmentation'
# Error processing image 208623: 'segmentation'
# Error processing image 493623: 'segmentation'
# Error processing image 579666: 'segmentation'
# Error processing image 131203: 'segmentation'
# Error processing image 191069: 'segmentation'
# Error processing image 213054: 'segmentation'
# Error processing image 565233: 'segmentation'
# Error processing image 411277: 'segmentation'
# Error processing image 179322: 'segmentation'
# Error processing image 221700: 'segmentation'
# Error processing image 8170: 'segmentation'
# Error processing image 564940: 'segmentation'
# Error processing image 285451: 'segmentation'
# Error processing image 459884: 'segmentation'
# Error processing image 81812: 'segmentation'
# Error processing image 247839: 'segmentation'
# Error processing image 318290: 'segmentation'
# Error processing image 554523: 'segmentation'
# Error processing image 149500: 'segmentation'
# Error processing image 205720: 'segmentation'
# Error processing image 168953: 'segmentation'
# Error processing image 173783: 'segmentation'
# Error processing image 181591: 'segmentation'
# Error processing image 384335: 'segmentation'
# Error processing image 547212: 'segmentation'
# Error processing image 549361: 'segmentation'
# Error processing image 443860: 'segmentation'
# Error processing image 579034: 'segmentation'
# Error processing image 29521: 'segmentation'
# Error processing image 30210: 'segmentation'
# Error processing image 309933: 'segmentation'
# Error processing image 69668: 'segmentation'
# Error processing image 4157: 'segmentation'
# Error processing image 233376: 'segmentation'
# Error processing image 567290: 'segmentation'
# Error processing image 515176: 'segmentation'
# Error processing image 292467: 'segmentation'
# Error processing image 186182: 'segmentation'
# Error processing image 49676: 'segmentation'
# Error processing image 461681: 'segmentation'
# Error processing image 105737: 'segmentation'
# Error processing image 452881: 'segmentation'
# Error processing image 90429: 'segmentation'
# Error processing image 202231: 'segmentation'
# Error processing image 160108: 'segmentation'
# Error processing image 160483: 'segmentation'
# Error processing image 292804: 'segmentation'
# Error processing image 241726: 'segmentation'
# Error processing image 473632: 'segmentation'
# Error processing image 41246: 'segmentation'
# Error processing image 148353: 'segmentation'
# Error processing image 321437: 'segmentation'
# Error processing image 293249: 'segmentation'
# Error processing image 108853: 'segmentation'
# Error processing image 341778: 'segmentation'
# Error processing image 64796: 'segmentation'
# Error processing image 322475: 'segmentation'
# Error processing image 156806: 'segmentation'
# Error processing image 421069: 'segmentation'
# Error processing image 188509: 'segmentation'
# Error processing image 500814: 'segmentation'
# Error processing image 122602: 'segmentation'
# Error processing image 363844: 'segmentation'
# Error processing image 135399: 'segmentation'
# Error processing image 265227: 'segmentation'
# Error processing image 548882: 'segmentation'
# Error processing image 334810: 'segmentation'
# Error processing image 409259: 'segmentation'
# Error processing image 135167: 'segmentation'
# Error processing image 110048: 'segmentation'
# Error processing image 487385: 'segmentation'
# Error processing image 508470: 'segmentation'
# Error processing image 202609: 'segmentation'
# Error processing image 4386: 'segmentation'
# Error processing image 502001: 'segmentation'
# Error processing image 150342: 'segmentation'
# Error processing image 430791: 'segmentation'
# Error processing image 301201: 'segmentation'
# Error processing image 130909: 'segmentation'
# Error processing image 208028: 'segmentation'
# Error processing image 63661: 'segmentation'
# Error processing image 59479: 'segmentation'
# Error processing image 369913: 'segmentation'
# Error processing image 148128: 'segmentation'
# Error processing image 314880: 'segmentation'
# Error processing image 186368: 'segmentation'
# Error processing image 5247: 'segmentation'
# Error processing image 519649: 'segmentation'
# Error processing image 149184: 'segmentation'
# Error processing image 62443: 'segmentation'
# Error processing image 277563: 'segmentation'
# Error processing image 494550: 'segmentation'
# Error processing image 287335: 'segmentation'
# Error processing image 347558: 'segmentation'
# Error processing image 14278: 'segmentation'
# Error processing image 437947: 'segmentation'
# Error processing image 349199: 'segmentation'
# Error processing image 377867: 'segmentation'
# Error processing image 298773: 'segmentation'
# Error processing image 135613: 'segmentation'
# Error processing image 342817: 'segmentation'
# Error processing image 27842: 'segmentation'
# Error processing image 141910: 'segmentation'
# Error processing image 139291: 'segmentation'
# Error processing image 325423: 'segmentation'
# Error processing image 404462: 'segmentation'
# Error processing image 456323: 'segmentation'
# Error processing image 549386: 'segmentation'
# Error processing image 147897: 'segmentation'
# Error processing image 254491: 'segmentation'
# Error processing image 439907: 'segmentation'
# Error processing image 544597: 'segmentation'
# Error processing image 314515: 'segmentation'
# Error processing image 555677: 'segmentation'
# Error processing image 415904: 'segmentation'
# Error processing image 101636: 'segmentation'
# Error processing image 315173: 'segmentation'
# Error processing image 397514: 'segmentation'
# Error processing image 443963: 'segmentation'
# Error processing image 260627: 'segmentation'
# Error processing image 87561: 'segmentation'
# Error processing image 540820: 'segmentation'
# Error processing image 300034: 'segmentation'
# Error processing image 220741: 'segmentation'
# Error processing image 221307: 'segmentation'
# Error processing image 380854: 'segmentation'
# Error processing image 69223: 'segmentation'
# Error processing image 468885: 'segmentation'
# Error processing image 246717: 'segmentation'
# Error processing image 56426: 'segmentation'
# Error processing image 448151: 'segmentation'
# Error processing image 404785: 'segmentation'
# Error processing image 436848: 'segmentation'
# Error processing image 28022: 'segmentation'
# Error processing image 391656: 'segmentation'
# Error processing image 506220: 'segmentation'
# Error processing image 97131: 'segmentation'
# Error processing image 54305: 'segmentation'
# Error processing image 511583: 'segmentation'
# Error processing image 245013: 'segmentation'
# Error processing image 93314: 'segmentation'
# Error processing image 161112: 'segmentation'
# Error processing image 317410: 'segmentation'
# Error processing image 141709: 'segmentation'
# Error processing image 412996: 'segmentation'
# Error processing image 120428: 'segmentation'
# Error processing image 546642: 'segmentation'
# Error processing image 80017: 'segmentation'
# Error processing image 94858: 'segmentation'
# Error processing image 203345: 'segmentation'
# Error processing image 537548: 'segmentation'
# Error processing image 521549: 'segmentation'
# Error processing image 215408: 'segmentation'
# Error processing image 133195: 'segmentation'
# Error processing image 414379: 'segmentation'
# Error processing image 112517: 'segmentation'
# Error processing image 335827: 'segmentation'
# Error processing image 521877: 'segmentation'
# Error processing image 183176: 'segmentation'
# Error processing image 386584: 'segmentation'
# Error processing image 440299: 'segmentation'
# Error processing image 451496: 'segmentation'
# Error processing image 46571: 'segmentation'
# Error processing image 307989: 'segmentation'
# Error processing image 486457: 'segmentation'
# Error processing image 101933: 'segmentation'
# Error processing image 56443: 'segmentation'
# Error processing image 233311: 'segmentation'
# Error processing image 542509: 'segmentation'
# Error processing image 165818: 'segmentation'
# Error processing image 463555: 'segmentation'
# Error processing image 27642: 'segmentation'
# Error processing image 92093: 'segmentation'
# Error processing image 413822: 'segmentation'
# Error processing image 14321: 'segmentation'
# Error processing image 558587: 'segmentation'
# Error processing image 556349: 'segmentation'
# Error processing image 457322: 'segmentation'
# Error processing image 56070: 'segmentation'
# Error processing image 475923: 'segmentation'
# Error processing image 86835: 'segmentation'
# Error processing image 461993: 'segmentation'
# Error processing image 235595: 'segmentation'
# Error processing image 534733: 'segmentation'
# Error processing image 520251: 'segmentation'
# Error processing image 30707: 'segmentation'
# Error processing image 82229: 'segmentation'
# Error processing image 254104: 'segmentation'
# Error processing image 189955: 'segmentation'
# Error processing image 436456: 'segmentation'
# Error processing image 466347: 'segmentation'
# Error processing image 265234: 'segmentation'
# Error processing image 455943: 'segmentation'
# Error processing image 322791: 'segmentation'
# Error processing image 120592: 'segmentation'
# Error processing image 84870: 'segmentation'
# Error processing image 576305: 'segmentation'
# Error processing image 391674: 'segmentation'
# Error processing image 206684: 'segmentation'
# Error processing image 430690: 'segmentation'
# Error processing image 577355: 'segmentation'
# Error processing image 68650: 'segmentation'
# Error processing image 503255: 'segmentation'
# Error processing image 222494: 'segmentation'
# Error processing image 61897: 'segmentation'
# Error processing image 371330: 'segmentation'
# Error processing image 238700: 'segmentation'
# Error processing image 357943: 'segmentation'
# Error processing image 134328: 'segmentation'
# Error processing image 345988: 'segmentation'
# Error processing image 518030: 'segmentation'
# Error processing image 249325: 'segmentation'
# Error processing image 526645: 'segmentation'
# Error processing image 233005: 'segmentation'
# Error processing image 385139: 'segmentation'
# Error processing image 80462: 'segmentation'
# Error processing image 577866: 'segmentation'
# Error processing image 193936: 'segmentation'
# Error processing image 306553: 'segmentation'
# Error processing image 422877: 'segmentation'
# Error processing image 364757: 'segmentation'
# Error processing image 235919: 'segmentation'
# Error processing image 103431: 'segmentation'
# Error processing image 2621: 'segmentation'
# Error processing image 301937: 'segmentation'
# Error processing image 105872: 'segmentation'
# Error processing image 127785: 'segmentation'
# Error processing image 198486: 'segmentation'
# Error processing image 327383: 'segmentation'
# Error processing image 398519: 'segmentation'
# Error processing image 239148: 'segmentation'
# Error processing image 86800: 'segmentation'
# Error processing image 192192: 'segmentation'
# Error processing image 102858: 'segmentation'
# Error processing image 267840: 'segmentation'
# Error processing image 361400: 'segmentation'
# Error processing image 566757: 'segmentation'
# Error processing image 107481: 'segmentation'
# Error processing image 274655: 'segmentation'
# Error processing image 260232: 'segmentation'
# Error processing image 224862: 'segmentation'
# Error processing image 460059: 'segmentation'
# Error processing image 439516: 'segmentation'
# Error processing image 577712: 'segmentation'
# Error processing image 308388: 'segmentation'
# Error processing image 390684: 'segmentation'
# Error processing image 555066: 'segmentation'
# Error processing image 62459: 'segmentation'
# Error processing image 192894: 'segmentation'
# Error processing image 181742: 'segmentation'
# Error processing image 405675: 'segmentation'
# Error processing image 108129: 'segmentation'
# Error processing image 76595: 'segmentation'
# Error processing image 186009: 'segmentation'
# Error processing image 282808: 'segmentation'
# Error processing image 224000: 'segmentation'
# Error processing image 171601: 'segmentation'
# Error processing image 303026: 'segmentation'
# Error processing image 314430: 'segmentation'
# Error processing image 240800: 'segmentation'
# Error processing image 191425: 'segmentation'
# Error processing image 524502: 'segmentation'
# Error processing image 552761: 'segmentation'
# Error processing image 164420: 'segmentation'
# Error processing image 204994: 'segmentation'
# Error processing image 130619: 'segmentation'
# Error processing image 328504: 'segmentation'
# Error processing image 173125: 'segmentation'
# Error processing image 551315: 'segmentation'
# Error processing image 278161: 'segmentation'
# Error processing image 244005: 'segmentation'
# Error processing image 536486: 'segmentation'
# Error processing image 390068: 'segmentation'
# Error processing image 263011: 'segmentation'
# Error processing image 122051: 'segmentation'
# Error processing image 390569: 'segmentation'
# Error processing image 44860: 'segmentation'
# Error processing image 483742: 'segmentation'
# Error processing image 473171: 'segmentation'
# Error processing image 72632: 'segmentation'
# Error processing image 343213: 'segmentation'
# Error processing image 169166: 'segmentation'
# Error processing image 150576: 'segmentation'
# Error processing image 495541: 'segmentation'
# Error processing image 458560: 'segmentation'
# Error processing image 358707: 'segmentation'
# Error processing image 252133: 'segmentation'
# Error processing image 309264: 'segmentation'
# Error processing image 564419: 'segmentation'
# Error processing image 533276: 'segmentation'
# Error processing image 234433: 'segmentation'
# Error processing image 536201: 'segmentation'
# Error processing image 383607: 'segmentation'
# Error processing image 353866: 'segmentation'
# Error processing image 255649: 'segmentation'
# Error processing image 208708: 'segmentation'
# Error processing image 74465: 'segmentation'
# Error processing image 196355: 'segmentation'
# Error processing image 494620: 'segmentation'
# Error processing image 136285: 'segmentation'
# Error processing image 176193: 'segmentation'
# Error processing image 432647: 'segmentation'
# Error processing image 393942: 'segmentation'
# Error processing image 56983: 'segmentation'
# Error processing image 170000: 'segmentation'
# Error processing image 289943: 'segmentation'
# Error processing image 286021: 'segmentation'
# Error processing image 26201: 'segmentation'
# Error processing image 400202: 'segmentation'
# Error processing image 81264: 'segmentation'
# Error processing image 507550: 'segmentation'
# Error processing image 194499: 'segmentation'
# Error processing image 274606: 'segmentation'
# Error processing image 186950: 'segmentation'
# Error processing image 35826: 'segmentation'
# Error processing image 267628: 'segmentation'
# Error processing image 165697: 'segmentation'
# Error processing image 513692: 'segmentation'
# Error processing image 144715: 'segmentation'
# Error processing image 6180: 'segmentation'
# Error processing image 513765: 'segmentation'
# Error processing image 389206: 'segmentation'
# Error processing image 391158: 'segmentation'
# Error processing image 511623: 'segmentation'
# Error processing image 316672: 'segmentation'
# Error processing image 199257: 'segmentation'
# Error processing image 547760: 'segmentation'
# Error processing image 287099: 'segmentation'
# Error processing image 87354: 'segmentation'
# Error processing image 245051: 'segmentation'
# Error processing image 194407: 'segmentation'
# Error processing image 517967: 'segmentation'
# Error processing image 108353: 'segmentation'
# Error processing image 518604: 'segmentation'
# Error processing image 116951: 'segmentation'
# Error processing image 114235: 'segmentation'
# Error processing image 552752: 'segmentation'
# Error processing image 268745: 'segmentation'
# Error processing image 448786: 'segmentation'
# Error processing image 101031: 'segmentation'
# Error processing image 503939: 'segmentation'
# Error processing image 342051: 'segmentation'
# Error processing image 204098: 'segmentation'
# Error processing image 379183: 'segmentation'
# Error processing image 470882: 'segmentation'
# Error processing image 457491: 'segmentation'
# Error processing image 178911: 'segmentation'
# Error processing image 76513: 'segmentation'
# Error processing image 216972: 'segmentation'
# Error processing image 279136: 'segmentation'
# Error processing image 506416: 'segmentation'
# Error processing image 25747: 'segmentation'
# Error processing image 224554: 'segmentation'
# Error processing image 290261: 'segmentation'
# Error processing image 503196: 'segmentation'
# Error processing image 575909: 'segmentation'
# Error processing image 407570: 'segmentation'
# Error processing image 110626: 'segmentation'
# Error processing image 25550: 'segmentation'
# Error processing image 263884: 'segmentation'
# Error processing image 414068: 'segmentation'
# Error processing image 560675: 'segmentation'
# Error processing image 327130: 'segmentation'
# Error processing image 403919: 'segmentation'
# Error processing image 439306: 'segmentation'
# Error processing image 451648: 'segmentation'
# Error processing image 219655: 'segmentation'
# Error processing image 130966: 'segmentation'
# Error processing image 216103: 'segmentation'
# Error processing image 552289: 'segmentation'
# Error processing image 445603: 'segmentation'
# Error processing image 378823: 'segmentation'
# Error processing image 463406: 'segmentation'
# Error processing image 18239: 'segmentation'
# Error processing image 363887: 'segmentation'
# Error processing image 168031: 'segmentation'
# Error processing image 128528: 'segmentation'
# Error processing image 500723: 'segmentation'
# Error processing image 313420: 'segmentation'
# Error processing image 371054: 'segmentation'
# Error processing image 153966: 'segmentation'
# Error processing image 351081: 'segmentation'
# Error processing image 476894: 'segmentation'
# Error processing image 479384: 'segmentation'
# Error processing image 480720: 'segmentation'
# Error processing image 490702: 'segmentation'
# Error processing image 45603: 'segmentation'
# Error processing image 452772: 'segmentation'
# Error processing image 93803: 'segmentation'
# Error processing image 398884: 'segmentation'
# Error processing image 360064: 'segmentation'
# Error processing image 502798: 'segmentation'
# Error processing image 11169: 'segmentation'
# Error processing image 310618: 'segmentation'
# Error processing image 195437: 'segmentation'
# Error processing image 290839: 'segmentation'
# Error processing image 449302: 'segmentation'
# Error processing image 151387: 'segmentation'
# Error processing image 578383: 'segmentation'
# Error processing image 288076: 'segmentation'
# Error processing image 530941: 'segmentation'
# Error processing image 354744: 'segmentation'
# Error processing image 262993: 'segmentation'
# Error processing image 476552: 'segmentation'
# Error processing image 386637: 'segmentation'
# Error processing image 531144: 'segmentation'
# Error processing image 331875: 'segmentation'
# Error processing image 228300: 'segmentation'
# Error processing image 111109: 'segmentation'
# Error processing image 283441: 'segmentation'
# Error processing image 542388: 'segmentation'
# Error processing image 214646: 'segmentation'
# Error processing image 69928: 'segmentation'
# Error processing image 436218: 'segmentation'
# Error processing image 457877: 'segmentation'
# Error processing image 125873: 'segmentation'
# Error processing image 536743: 'segmentation'
# Error processing image 72829: 'segmentation'
# Error processing image 98881: 'segmentation'
# Error processing image 41924: 'segmentation'
# Error processing image 394322: 'segmentation'
# Error processing image 96075: 'segmentation'
# Error processing image 93120: 'segmentation'
# Error processing image 560349: 'segmentation'
# Error processing image 498856: 'segmentation'
# Error processing image 135281: 'segmentation'
# Error processing image 427820: 'segmentation'
# Error processing image 399570: 'segmentation'
# Error processing image 70332: 'segmentation'
# Error processing image 255592: 'segmentation'
# Error processing image 476767: 'segmentation'
# Error processing image 411043: 'segmentation'
# Error processing image 206876: 'segmentation'
# Error processing image 562347: 'segmentation'
# Error processing image 243852: 'segmentation'
# Error processing image 485447: 'segmentation'
# Error processing image 230995: 'segmentation'
# Error processing image 9420: 'segmentation'
# Error processing image 352206: 'segmentation'
# Error processing image 480311: 'segmentation'
# Error processing image 480663: 'segmentation'
# Error processing image 152000: 'segmentation'
# Error processing image 172718: 'segmentation'
# Error processing image 152252: 'segmentation'
# Error processing image 354948: 'segmentation'
# Error processing image 203096: 'segmentation'
# Error processing image 292685: 'segmentation'
# Error processing image 196798: 'segmentation'
# Error processing image 131942: 'segmentation'
# Error processing image 275717: 'segmentation'
# Error processing image 359039: 'segmentation'
# Error processing image 59952: 'segmentation'
# Error processing image 215633: 'segmentation'
# Error processing image 369799: 'segmentation'
# Error processing image 153994: 'segmentation'
# Error processing image 1682: 'segmentation'
# Error processing image 570952: 'segmentation'
# Error processing image 544638: 'segmentation'
# Error processing image 539413: 'segmentation'
# Error processing image 149165: 'segmentation'
# Error processing image 118579: 'segmentation'
# Error processing image 309424: 'segmentation'
# Error processing image 229270: 'segmentation'
# Error processing image 272111: 'segmentation'
# Error processing image 251404: 'segmentation'
# Error processing image 115765: 'segmentation'
# Error processing image 480179: 'segmentation'
# Error processing image 101785: 'segmentation'
# Error processing image 401197: 'segmentation'
# Error processing image 555582: 'segmentation'
# Error processing image 131453: 'segmentation'
# Error processing image 374649: 'segmentation'
# Error processing image 440830: 'segmentation'
# Error processing image 386035: 'segmentation'
# Error processing image 320106: 'segmentation'
# Error processing image 112830: 'segmentation'
# Error processing image 571823: 'segmentation'
# Error processing image 139472: 'segmentation'
# Error processing image 526353: 'segmentation'
# Error processing image 443363: 'segmentation'
# Error processing image 559470: 'segmentation'
# Error processing image 490178: 'segmentation'
# Error processing image 460294: 'segmentation'
# Error processing image 481130: 'segmentation'
# Error processing image 341957: 'segmentation'
# Error processing image 372009: 'segmentation'
# Error processing image 453162: 'segmentation'
# Error processing image 137573: 'segmentation'
# Error processing image 517388: 'segmentation'
# Error processing image 186899: 'segmentation'
# Error processing image 201241: 'segmentation'
# Error processing image 42225: 'segmentation'
# Error processing image 428366: 'segmentation'
# Error processing image 360128: 'segmentation'
# Error processing image 515777: 'segmentation'
# Error processing image 232544: 'segmentation'
# Error processing image 81081: 'segmentation'
# Error processing image 305626: 'segmentation'
# Error processing image 290432: 'segmentation'
# Error processing image 223174: 'segmentation'
# Error processing image 456690: 'segmentation'
# Error processing image 95375: 'segmentation'
# Error processing image 240393: 'segmentation'
# Error processing image 88899: 'segmentation'
# Error processing image 229765: 'segmentation'
# Error processing image 548500: 'segmentation'
# Error processing image 540564: 'segmentation'
# Error processing image 569674: 'segmentation'
# Error processing image 31390: 'segmentation'
# Error processing image 182849: 'segmentation'
# Error processing image 273321: 'segmentation'
# Error processing image 207763: 'segmentation'
# Error processing image 428178: 'segmentation'
# Error processing image 90058: 'segmentation'
# Error processing image 447194: 'segmentation'
# Error processing image 176592: 'segmentation'
# Error processing image 524247: 'segmentation'
# Error processing image 451263: 'segmentation'
# Error processing image 579402: 'segmentation'
# Error processing image 529348: 'segmentation'
# Error processing image 212842: 'segmentation'
# Error processing image 359260: 'segmentation'
# Error processing image 529266: 'segmentation'
# Error processing image 573179: 'segmentation'
# Error processing image 221083: 'segmentation'
# Error processing image 124664: 'segmentation'
# Error processing image 303267: 'segmentation'
# Error processing image 423731: 'segmentation'
# Error processing image 340478: 'segmentation'
# Error processing image 460307: 'segmentation'
# Error processing image 570788: 'segmentation'
# Error processing image 402250: 'segmentation'
# Error processing image 359838: 'segmentation'
# Error processing image 449039: 'segmentation'
# Error processing image 18654: 'segmentation'
# Error processing image 555299: 'segmentation'
# Error processing image 412304: 'segmentation'
# Error processing image 377984: 'segmentation'
# Error processing image 86442: 'segmentation'
# Error processing image 242779: 'segmentation'
# Error processing image 99269: 'segmentation'
# Error processing image 535933: 'segmentation'
# Error processing image 172137: 'segmentation'
# Error processing image 546854: 'segmentation'
# Error processing image 201970: 'segmentation'
# Error processing image 161011: 'segmentation'
# Error processing image 513342: 'segmentation'
# Error processing image 156375: 'segmentation'
# Error processing image 10644: 'segmentation'
# Error processing image 74832: 'segmentation'
# Error processing image 301155: 'segmentation'
# Error processing image 8711: 'segmentation'
# Error processing image 403096: 'segmentation'
# Error processing image 374087: 'segmentation'
# Error processing image 533137: 'segmentation'
# Error processing image 358994: 'segmentation'
# Error processing image 14874: 'segmentation'
# Error processing image 188417: 'segmentation'
# Error processing image 333156: 'segmentation'
# Error processing image 160260: 'segmentation'
# Error processing image 347675: 'segmentation'
# Error processing image 10432: 'segmentation'
# Error processing image 377706: 'segmentation'
# Error processing image 257328: 'segmentation'
# Error processing image 19176: 'segmentation'
# Error processing image 555131: 'segmentation'
# Error processing image 32300: 'segmentation'
# Error processing image 258399: 'segmentation'
# Error processing image 37671: 'segmentation'
# Error processing image 206618: 'segmentation'
# Error processing image 229274: 'segmentation'
# Error processing image 324308: 'segmentation'
# Error processing image 468777: 'segmentation'
# Error processing image 66179: 'segmentation'
# Error processing image 507318: 'segmentation'
# Error processing image 193387: 'segmentation'
# Error processing image 472282: 'segmentation'
# Error processing image 63671: 'segmentation'
# Error processing image 53958: 'segmentation'
# Error processing image 446920: 'segmentation'
# Error processing image 509158: 'segmentation'
# Error processing image 538888: 'segmentation'
# Error processing image 359432: 'segmentation'
# Error processing image 378098: 'segmentation'
# Error processing image 103490: 'segmentation'
# Error processing image 184121: 'segmentation'
# Error processing image 266176: 'segmentation'
# Error processing image 63549: 'segmentation'
# Error processing image 135785: 'segmentation'
# Error processing image 338375: 'segmentation'
# Error processing image 377111: 'segmentation'
# Error processing image 99592: 'segmentation'
# Error processing image 99647: 'segmentation'
# Error processing image 199133: 'segmentation'
# Error processing image 421703: 'segmentation'
# Error processing image 493683: 'segmentation'
# Error processing image 439092: 'segmentation'
# Error processing image 60970: 'segmentation'
# Error processing image 335976: 'segmentation'
# Error processing image 185444: 'segmentation'
# Error processing image 207178: 'segmentation'
# Error processing image 516813: 'segmentation'
# Error processing image 137622: 'segmentation'
# Error processing image 292170: 'segmentation'
# Error processing image 381195: 'segmentation'
# Error processing image 831: 'segmentation'
# Error processing image 145824: 'segmentation'
# Error processing image 131527: 'segmentation'
# Error processing image 121788: 'segmentation'
# Error processing image 259233: 'segmentation'
# Error processing image 368268: 'segmentation'
# Error processing image 368528: 'segmentation'
# Error processing image 304834: 'segmentation'
# Error processing image 84130: 'segmentation'
# Error processing image 423480: 'segmentation'
# Error processing image 318147: 'segmentation'
# Error processing image 134285: 'segmentation'
# Error processing image 536791: 'segmentation'
# Error processing image 415135: 'segmentation'
# Error processing image 392781: 'segmentation'
# Error processing image 531115: 'segmentation'
# Error processing image 95808: 'segmentation'
# Error processing image 384523: 'segmentation'
# Error processing image 93735: 'segmentation'
# Error processing image 302599: 'segmentation'
# Error processing image 558528: 'segmentation'
# Error processing image 376545: 'segmentation'
# Error processing image 160351: 'segmentation'
# Error processing image 50245: 'segmentation'
# ...
# Error processing image 564654: 'segmentation'
# Error processing image 18424: 'segmentation'
# Error processing image 479867: 'segmentation'
# Error processing image 41993: 'segmentation'
# Error processing image 345803: 'segmentation'
# Error processing image 497804: 'segmentation'
# Error processing image 68069: 'segmentation'
# Error processing image 553392: 'segmentation'
# Error processing image 418506: 'segmentation'
# Error processing image 35245: 'segmentation'
# Error processing image 411399: 'segmentation'
# Error processing image 249609: 'segmentation'
# Error processing image 59960: 'segmentation'
# Error processing image 85086: 'segmentation'
# Error processing image 186493: 'segmentation'
# Error processing image 517261: 'segmentation'
# Error processing image 75800: 'segmentation'
# Error processing image 133482: 'segmentation'
# Error processing image 181953: 'segmentation'
# Error processing image 439199: 'segmentation'
# Creating val masks: 100%|██████████| 118287/118287 [00:03<00:00, 38482.75it/s]
# Error processing image 565201: 'segmentation'
# Error processing image 121792: 'segmentation'
# Error processing image 370728: 'segmentation'
# Error processing image 556599: 'segmentation'
# Error processing image 168296: 'segmentation'
# Error processing image 545257: 'segmentation'
# Error processing image 250909: 'segmentation'
# Error processing image 120230: 'segmentation'
# Error processing image 250958: 'segmentation'
# Error processing image 88870: 'segmentation'
# Error processing image 45230: 'segmentation'
# Error processing image 284448: 'segmentation'
# Error processing image 288683: 'segmentation'
# Error processing image 186155: 'segmentation'
# Error processing image 359360: 'segmentation'
# Error processing image 130069: 'segmentation'
# Error processing image 580434: 'segmentation'
# Error processing image 404750: 'segmentation'
# Error processing image 131127: 'segmentation'
# Error processing image 467645: 'segmentation'
# Error processing image 124132: 'segmentation'
# Error processing image 142208: 'segmentation'
# Error processing image 305826: 'segmentation'
# Error processing image 522534: 'segmentation'
# Error processing image 326354: 'segmentation'
# Error processing image 429182: 'segmentation'
# Error processing image 551802: 'segmentation'
# Error processing image 525529: 'segmentation'
# Error processing image 283018: 'segmentation'
# Error processing image 198654: 'segmentation'
# Error processing image 571656: 'segmentation'
# Error processing image 122527: 'segmentation'
# Error processing image 101571: 'segmentation'
# Error processing image 119087: 'segmentation'
# Error processing image 512658: 'segmentation'
# Error processing image 521763: 'segmentation'
# Error processing image 121344: 'segmentation'
# Error processing image 8228: 'segmentation'
# Error processing image 398514: 'segmentation'
# Error processing image 36433: 'segmentation'
# Error processing image 542321: 'segmentation'
# Error processing image 395120: 'segmentation'
# Error processing image 165680: 'segmentation'
# Error processing image 460364: 'segmentation'
# Error processing image 111148: 'segmentation'
# Error processing image 456545: 'segmentation'
# Error processing image 149630: 'segmentation'
# Error processing image 84268: 'segmentation'
# Error processing image 488731: 'segmentation'
# Error processing image 389935: 'segmentation'
# Error processing image 266777: 'segmentation'
# Error processing image 199072: 'segmentation'
# Error processing image 91137: 'segmentation'
# Error processing image 488707: 'segmentation'
# Error processing image 131812: 'segmentation'
# Error processing image 376407: 'segmentation'
# Error processing image 31358: 'segmentation'
# Error processing image 335871: 'segmentation'
# Error processing image 193062: 'segmentation'
# Error processing image 25801: 'segmentation'
# Error processing image 271941: 'segmentation'
# Error processing image 327178: 'segmentation'
# Error processing image 415499: 'segmentation'
# Error processing image 292157: 'segmentation'
# Error processing image 276386: 'segmentation'
# Error processing image 295778: 'segmentation'
# Error processing image 201417: 'segmentation'
# Error processing image 415275: 'segmentation'
# Error processing image 444649: 'segmentation'
# Error processing image 247397: 'segmentation'
# Error processing image 144419: 'segmentation'
# Error processing image 418057: 'segmentation'
# Error processing image 508915: 'segmentation'
# Error processing image 89318: 'segmentation'
# Error processing image 532128: 'segmentation'
# Error processing image 433029: 'segmentation'
# Error processing image 351364: 'segmentation'
# Error processing image 554665: 'segmentation'
# Error processing image 186099: 'segmentation'
# Error processing image 572888: 'segmentation'
# Error processing image 180966: 'segmentation'
# Error processing image 84670: 'segmentation'
# Error processing image 330598: 'segmentation'
# Error processing image 95752: 'segmentation'
# Error processing image 214232: 'segmentation'
# Error processing image 50846: 'segmentation'
# Error processing image 131498: 'segmentation'
# Error processing image 577283: 'segmentation'
# Error processing image 55516: 'segmentation'
# Error processing image 261742: 'segmentation'
# Error processing image 176523: 'segmentation'
# Error processing image 213148: 'segmentation'
# Error processing image 169155: 'segmentation'
# Error processing image 422611: 'segmentation'
# Error processing image 348966: 'segmentation'
# Error processing image 573052: 'segmentation'
# Error processing image 254902: 'segmentation'
# Error processing image 411257: 'segmentation'
# Error processing image 272439: 'segmentation'
# Error processing image 197265: 'segmentation'
# Error processing image 293353: 'segmentation'
# Error processing image 121647: 'segmentation'
# Error processing image 545308: 'segmentation'
# Error processing image 304473: 'segmentation'
# Error processing image 475146: 'segmentation'
# Error processing image 51819: 'segmentation'
# Error processing image 234745: 'segmentation'
# Error processing image 104588: 'segmentation'
# Error processing image 559511: 'segmentation'
# Error processing image 401846: 'segmentation'
# Error processing image 307259: 'segmentation'
# Error processing image 277200: 'segmentation'
# Error processing image 262545: 'segmentation'
# Error processing image 86989: 'segmentation'
# Error processing image 563655: 'segmentation'
# Error processing image 53729: 'segmentation'
# Error processing image 558942: 'segmentation'
# Error processing image 240225: 'segmentation'
# Error processing image 205086: 'segmentation'
# Error processing image 369443: 'segmentation'
# Error processing image 475306: 'segmentation'
# Error processing image 391325: 'segmentation'
# Error processing image 476321: 'segmentation'
# Error processing image 234118: 'segmentation'
# Error processing image 224164: 'segmentation'
# Error processing image 171158: 'segmentation'
# Error processing image 182904: 'segmentation'
# Error processing image 515743: 'segmentation'
# Error processing image 516791: 'segmentation'
# Error processing image 85981: 'segmentation'
# Error processing image 13146: 'segmentation'
# Error processing image 299563: 'segmentation'
# Error processing image 42103: 'segmentation'
# Error processing image 504039: 'segmentation'
# Error processing image 250998: 'segmentation'
# Error processing image 329054: 'segmentation'
# Error processing image 79423: 'segmentation'
# Error processing image 144983: 'segmentation'
# Error processing image 513618: 'segmentation'
# Error processing image 528507: 'segmentation'
# Error processing image 447084: 'segmentation'
# Error processing image 327758: 'segmentation'
# Error processing image 238140: 'segmentation'
# Error processing image 232467: 'segmentation'
# Error processing image 492078: 'segmentation'
# Error processing image 501967: 'segmentation'
# Error processing image 49286: 'segmentation'
# Error processing image 337745: 'segmentation'
# Error processing image 303708: 'segmentation'
# Error processing image 430950: 'segmentation'
# Error processing image 512304: 'segmentation'
# Error processing image 144199: 'segmentation'
# Error processing image 233093: 'segmentation'
# Error processing image 119561: 'segmentation'
# Error processing image 395271: 'segmentation'
# Error processing image 480376: 'segmentation'
# Error processing image 15071: 'segmentation'
# Error processing image 356011: 'segmentation'
# Error processing image 16283: 'segmentation'
# Error processing image 486300: 'segmentation'
# Error processing image 212440: 'segmentation'
# Error processing image 445829: 'segmentation'
# Error processing image 331278: 'segmentation'
# Error processing image 5459: 'segmentation'
# Error processing image 431531: 'segmentation'
# Error processing image 246918: 'segmentation'
# Error processing image 251262: 'segmentation'
# Error processing image 487061: 'segmentation'
# Error processing image 394975: 'segmentation'
# Error processing image 234603: 'segmentation'
# Error processing image 223601: 'segmentation'
# Error processing image 367562: 'segmentation'
# Error processing image 387301: 'segmentation'
# Error processing image 516541: 'segmentation'
# Error processing image 271701: 'segmentation'
# Error processing image 413510: 'segmentation'
# Error processing image 357456: 'segmentation'
# Error processing image 439689: 'segmentation'
# Error processing image 219474: 'segmentation'
# Error processing image 356330: 'segmentation'
# Error processing image 543276: 'segmentation'
# Error processing image 60136: 'segmentation'
# Error processing image 69428: 'segmentation'
# Error processing image 199577: 'segmentation'
# Error processing image 305550: 'segmentation'
# Error processing image 248315: 'segmentation'
# Error processing image 24310: 'segmentation'
# Error processing image 101450: 'segmentation'
# Error processing image 51390: 'segmentation'
# Error processing image 175281: 'segmentation'
# Error processing image 563707: 'segmentation'
# Error processing image 149604: 'segmentation'
# Error processing image 323226: 'segmentation'
# Error processing image 252846: 'segmentation'
# Error processing image 469832: 'segmentation'
# Error processing image 203603: 'segmentation'
# Error processing image 5028: 'segmentation'
# Error processing image 175651: 'segmentation'
# Error processing image 213214: 'segmentation'
# Error processing image 296477: 'segmentation'
# Error processing image 158647: 'segmentation'
# Error processing image 201738: 'segmentation'
# Error processing image 56896: 'segmentation'
# Error processing image 214856: 'segmentation'
# Error processing image 236596: 'segmentation'
# Error processing image 399353: 'segmentation'
# Error processing image 234430: 'segmentation'
# Error processing image 230712: 'segmentation'
# Error processing image 55527: 'segmentation'
# Error processing image 404545: 'segmentation'
# Error processing image 66420: 'segmentation'
# Error processing image 350506: 'segmentation'
# Error processing image 93298: 'segmentation'
# Error processing image 479690: 'segmentation'
# Error processing image 565146: 'segmentation'
# Error processing image 83672: 'segmentation'
# Error processing image 550839: 'segmentation'
# Error processing image 402505: 'segmentation'
# Error processing image 482201: 'segmentation'
# Error processing image 123177: 'segmentation'
# Error processing image 532155: 'segmentation'
# Error processing image 361334: 'segmentation'
# Error processing image 365948: 'segmentation'
# Error processing image 274266: 'segmentation'
# Error processing image 194056: 'segmentation'
# Error processing image 134211: 'segmentation'
# Error processing image 516049: 'segmentation'
# Error processing image 316970: 'segmentation'
# Error processing image 546147: 'segmentation'
# Error processing image 354791: 'segmentation'
# Error processing image 379944: 'segmentation'
# Error processing image 198042: 'segmentation'
# Error processing image 426975: 'segmentation'
# Error processing image 387606: 'segmentation'
# Error processing image 94714: 'segmentation'
# Error processing image 569553: 'segmentation'
# Error processing image 472209: 'segmentation'
# Error processing image 19642: 'segmentation'
# Error processing image 268909: 'segmentation'
# Error processing image 142545: 'segmentation'
# Error processing image 547777: 'segmentation'
# Error processing image 49429: 'segmentation'
# Error processing image 375321: 'segmentation'
# Error processing image 250249: 'segmentation'
# Error processing image 564302: 'segmentation'
# Error processing image 510456: 'segmentation'
# Error processing image 306822: 'segmentation'
# Error processing image 279777: 'segmentation'
# Error processing image 545549: 'segmentation'
# Error processing image 576227: 'segmentation'
# Error processing image 126073: 'segmentation'
# Error processing image 226679: 'segmentation'
# Error processing image 374391: 'segmentation'
# Error processing image 415710: 'segmentation'
# Error processing image 249111: 'segmentation'
# Error processing image 49713: 'segmentation'
# Error processing image 35351: 'segmentation'
# Error processing image 233642: 'segmentation'
# Error processing image 304221: 'segmentation'
# Error processing image 179961: 'segmentation'
# Error processing image 326035: 'segmentation'
# Error processing image 122959: 'segmentation'
# Error processing image 363298: 'segmentation'
# Error processing image 265161: 'segmentation'
# Error processing image 86581: 'segmentation'
# Error processing image 98205: 'segmentation'
# Error processing image 445671: 'segmentation'
# Error processing image 392319: 'segmentation'
# Error processing image 329090: 'segmentation'
# Error processing image 171885: 'segmentation'
# Error processing image 531056: 'segmentation'
# Error processing image 247982: 'segmentation'
# Error processing image 473102: 'segmentation'
# Error processing image 311173: 'segmentation'
# Error processing image 401045: 'segmentation'
# Error processing image 49017: 'segmentation'
# Error processing image 287027: 'segmentation'
# Error processing image 534001: 'segmentation'
# Error processing image 285405: 'segmentation'
# Error processing image 100223: 'segmentation'
# Error processing image 55460: 'segmentation'
# Error processing image 294751: 'segmentation'
# Error processing image 340528: 'segmentation'
# Error processing image 321633: 'segmentation'
# Error processing image 577723: 'segmentation'
# Error processing image 334285: 'segmentation'
# Error processing image 531171: 'segmentation'
# Error processing image 125910: 'segmentation'
# Error processing image 35763: 'segmentation'
# Error processing image 218762: 'segmentation'
# Error processing image 31454: 'segmentation'
# Error processing image 496153: 'segmentation'
# Error processing image 80789: 'segmentation'
# Error processing image 40478: 'segmentation'
# Error processing image 400218: 'segmentation'
# Error processing image 339278: 'segmentation'
# Error processing image 439057: 'segmentation'
# Error processing image 220453: 'segmentation'
# Error processing image 19181: 'segmentation'
# Error processing image 451701: 'segmentation'
# Error processing image 348597: 'segmentation'
# Error processing image 226055: 'segmentation'
# Error processing image 309695: 'segmentation'
# Error processing image 395293: 'segmentation'
# Error processing image 342307: 'segmentation'
# Error processing image 99671: 'segmentation'
# Error processing image 143095: 'segmentation'
# Error processing image 180682: 'segmentation'
# Error processing image 432062: 'segmentation'
# Error processing image 347405: 'segmentation'
# Error processing image 56550: 'segmentation'
# Error processing image 390608: 'segmentation'
# Error processing image 227675: 'segmentation'
# Error processing image 117327: 'segmentation'
# Error processing image 135676: 'segmentation'
# Error processing image 155379: 'segmentation'
# Error processing image 53136: 'segmentation'
# Error processing image 360271: 'segmentation'
# Error processing image 471345: 'segmentation'
# Error processing image 444010: 'segmentation'
# Error processing image 565004: 'segmentation'
# Error processing image 516168: 'segmentation'
# Error processing image 547503: 'segmentation'
# Error processing image 475546: 'segmentation'
# ✓ Training masks created successfully!
# ✓ Verified: 0 mask files created in /content/drive/MyDrive/AI_Vision_Extract_Nov25/data/COCO2017_SAMPLE/mask_val2017

# %%
# Check if masks exist

mask_files = os.listdir(masks_output_dir)
print(f"Number of masks created: {len(mask_files)}")
print(f"First 5 mask files: {mask_files[:5]}")

# Check file sizes
total_size = sum(os.path.getsize(os.path.join(masks_output_dir, f)) for f in mask_files)
print(f"Total disk space used: {total_size / (1024**3):.2f} GB")
# Out:
# Number of masks created: 0
# First 5 mask files: []
# Total disk space used: 0.00 GB
