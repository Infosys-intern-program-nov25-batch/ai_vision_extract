# %% [markdown]
# ### Essential NumPy and Pandas Functions for Data Analysis
#
# Let's look at practical code snippets that demonstrate the most useful NumPy and pandas methods for data analysis in Python. You can use these in a Jupyter notebook for experimentation and workflow mastery.

# %% [markdown]
# #### NumPy Basics for Data Analysis
# Import NumPy:

# %%
import numpy as np

# %% [markdown]
# 1. Creating Arrays

# %%
arr = np.array([1, 2, 3, 4])            # 1D array
matrix = np.array([[1, 2], [3, 4]])     # 2D array
zeros = np.zeros((2, 3))                # 2x3 array of zeros
ones = np.ones((2, 3))                  # 2x3 array of ones
rnd = np.random.rand(2, 3)              # 2x3 array of random floats

# %% [markdown]
# 2. Array Shape, Reshape, Flatten

# %%
print(arr.shape)                # (4,)
reshaped = matrix.reshape((4, 1))   # Reshape to 4 rows, 1 column
flat = matrix.ravel()               # Flatten to 1D array
# Out:
# (4,)

# %% [markdown]
# 3. Indexing and Slicing

# %%
print(matrix[0, 1])    # element at first row, second column
print(arr[1:3])        # slice elements 1 to 2
# Out:
# 2
# [2 3]

# %% [markdown]
# 4. Basic Math Operations

# %%
a = np.array([10, 20, 30])
b = np.array([1, 2, 3])
print(a + b)           # [11 22 33]
print(a - b)           # [ 9 18 27]
print(a * b)           # [10 40 90]
print(a / b)           # [10. 10. 10.]
# Out:
# [11 22 33]
# [ 9 18 27]
# [10 40 90]
# [10. 10. 10.]

# %% [markdown]
# 5. Aggregation and Stats

# %%
np.sum(arr)                 # 10
np.mean(arr)                # 2.5
np.std(arr)                 # Standard deviation
np.min(arr), np.max(arr)    # Min and max values
# Out:
# (1, 4)

# %% [markdown]
# 6. Dot Product, Matrix Ops

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
dot = np.dot(a, b)          # 1*4 + 2*5 + 3*6 = 32
mat = np.array([[1, 2], [3, 4]])
mat2 = np.array([[5, 6], [7, 8]])
matprod = np.matmul(mat, mat2) # Matrix multiplication

# %% [markdown]
# 7. Logical and Filtering

# %%
arr[arr > 2]                # Returns [3, 4]
np.where(arr > 2)           # Indices where condition is true
# Out:
# (array([2, 3], dtype=int64),)

# %% [markdown]
# 8. Random Sampling

# %%
np.random.randint(0, 100, size=5) # 5 random ints 0-99
np.random.choice([0, 1], size=10) # 10 random 0s or 1s
# Out:
# array([0, 0, 1, 0, 1, 0, 0, 1, 1, 1])

# %% [markdown]
# #### Pandas Basics for Data Analysis
# Import pandas:

# %%
import pandas as pd

# %% [markdown]
# 1. Creating DataFrames

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data) # Create DataFrame

# %% [markdown]
# 2. Inspecting Data

# %%
df.head()                # First 5 rows
df.tail(3)                # Last 3 rows
df.info()                 # DataFrame info + datatypes
df.describe()             # Summary statistics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %% [markdown]
# 3. Selecting Data

# %%
df['A']                   # Get column A
df.loc[0]                 # Row by label (index 0)
df.iloc[1:3]              # Rows 1-2 by position
df[df['A'] > 1]           # Filter rows where A > 1
# Out:
#    A  B
# 1  2  5
# 2  3  6

# %% [markdown]
# 4. Adding/Dropping Columns

# %%
df['C'] = df['A'] + df['B']     # Add new column
new_df = df.drop('B', axis=1)   # Drop column B

# %% [markdown]
# 5. Missing Values & Types

# %%
df.isnull().sum()               # Missing values per column
df.fillna(0)                    # Replace NaNs with 0
df['A'] = df['A'].astype(float) # Change column type

# %% [markdown]
# 6. Grouping and Aggregation

# %%
grouped = df.groupby('A').sum()   # Sum columns, grouped by values in A
df['A'].value_counts()            # Count unique values in A
# Out:
# A
# 1.0    1
# 2.0    1
# 3.0    1
# Name: count, dtype: int64

# %% [markdown]
# 7. Sorting

# %%
df.sort_values('B', ascending=False)  # Sort by column B
# Out:
#      A  B  C
# 2  3.0  6  9
# 1  2.0  5  7
# 0  1.0  4  5

# %% [markdown]
# 8. Reading/Writing Files

# %%
df.to_csv('mydata.csv') # Save to CSV
df = pd.read_csv('mydata.csv') # Load from CSV
df.head()
# Out:
#    Unnamed: 0  age  salary department  years_experience  is_manager
# 0           0   56   38392         IT              -0.8           0
# 1           1   46   60535  Marketing               3.4           1
# 2           2   32  108603         HR               5.0           1
# 3           3   25   82256         HR               4.2           1
# 4           4   38  119135         HR               4.1           1

# %% [markdown]
# 9. Apply/Map Functions

# %%
df['A_squared'] = df['A'].apply(lambda x: x**2) # Apply to column
df['B_label'] = df['B'].map({4: 'Low', 5: 'Med', 6: 'High'}) # Map values
df.sample(3)
# Out:
#      A  B  C  A_squared B_label
# 2  3.0  6  9        9.0    High
# 0  1.0  4  5        1.0     Low
# 1  2.0  5  7        4.0     Med

# %% [markdown]
# ### Task:

# %% [markdown]
# - Generated a Synthetic Dataset with columns of `age`, `salary`, `department`, `years_experience`, and `is_manager`.

# %%
np.random.seed(42) # For reproducibility
n_samples = 100 # Number of samples

data = {
    'age': np.random.randint(18, 60, size=n_samples),
    'salary': np.random.randint(30000, 120000, size=n_samples),
    'department': np.random.choice(['IT', 'HR', 'Finance', 'Marketing'], size=n_samples),
    'years_experience': np.round(np.random.normal(5, 2, size=n_samples), 1),
    'is_manager': np.random.choice([0, 1], size=n_samples)
}
df = pd.DataFrame(data)

# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
np.random.seed(42) # For reproducibility
n_samples = 100 # Number of samples

# %% [markdown]
# ## Creating data set

# %%
data = {
    'age': np.random.randint(18, 60, size=n_samples),
    'salary': np.random.randint(30000, 120000, size=n_samples),
    'department': np.random.choice(['IT', 'HR', 'Finance', 'Marketing'], size=n_samples),
    'years_experience': np.round(np.random.normal(5, 2, size=n_samples), 1),
    'is_manager': np.random.choice([0, 1], size=n_samples)
}
# Convert to DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# Q1. View data structure

# %%
# View first 5 rows
df.head()
# Out:
#    age  salary department  years_experience  is_manager
# 0   56   38392         IT              -0.8           0
# 1   46   60535  Marketing               3.4           1
# 2   32  108603         HR               5.0           1
# 3   25   82256         HR               4.2           1
# 4   38  119135         HR               4.1           1

# %%
#view last few rows
df.tail()
# Out:
#     age  salary department  years_experience  is_manager
# 95   59   82662         IT               4.0           0
# 96   56   42688         HR               4.4           1
# 97   58   55342  Marketing               6.0           0
# 98   45   67157         HR              11.4           0
# 99   24   97863         HR               5.2           1

# %%
# View data shape
print("Shape of DataFrame:", df.shape)

# View column names
print("Columns:", df.columns.tolist())
# Out:
# Shape of DataFrame: (100, 5)
# Columns: ['age', 'salary', 'department', 'years_experience', 'is_manager']

# %% [markdown]
# Q2. Get DataFrame Info and Summary Stats

# %%
# Get info about DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               100 non-null    int32
#  1   salary            100 non-null    int32
#  2   department        100 non-null    object
#  3   years_experience  100 non-null    float64
#  4   is_manager        100 non-null    int64
# dtypes: float64(1), int32(2), int64(1), object(1)
# memory usage: 3.3+ KB

# %%
# Get summary statistics for numeric columns
df.describe()
# Out:
#               age         salary  years_experience  is_manager
# count  100.000000     100.000000        100.000000  100.000000
# mean    37.910000   77809.160000          4.823000    0.470000
# std     12.219454   26058.643576          2.237822    0.501614
# min     18.000000   30206.000000         -0.800000    0.000000
# 25%     26.750000   55141.000000          3.475000    0.000000
# 50%     38.000000   80932.000000          4.700000    0.000000
# 75%     46.250000   98107.250000          6.000000    1.000000
# max     59.000000  119474.000000         11.400000    1.000000

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# age                 0
# salary              0
# department          0
# years_experience    0
# is_manager          0
# dtype: int64

# %% [markdown]
# Q3. Do Simple Numpy Operations

# %%
# Example: basic numpy operations
arr = np.array([1, 2, 3, 4, 5])

print("Array:", arr)
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))
print("Standard Deviation:", np.std(arr))
print("Max value:", np.max(arr))
print("Min value:", np.min(arr))
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Sum: 15
# Standard Deviation: 1.4142135623730951
# Max value: 5
# Min value: 1

# %% [markdown]
# Q4. Filtering and Indexing Rows

# %%
# Filter employees with salary greater than 80,000
high_salary = df[df['salary'] > 80000]
print(high_salary.head())

# Filter employees from IT department
it_employees = df[df['department'] == 'IT']
print(it_employees.head())

# Select specific columns
print(df[['age', 'salary', 'department']].head())
# Out:
#    age  salary department  years_experience  is_manager
# 2   32  108603         HR               5.0           1
# 3   25   82256         HR               4.2           1
# 4   38  119135         HR               4.1           1
# 6   36  107373    Finance               6.7           1
# 7   40  109575  Marketing               6.9           0
#     age  salary department  years_experience  is_manager
# 0    56   38392         IT              -0.8           0
# 9    28   93335         IT               1.2           1
# 10   41   40965         IT               9.5           1
# 15   39   57266         IT               5.8           1
# 30   32   86044         IT               4.7           0
#    age  salary department
# 0   56   38392         IT
# 1   46   60535  Marketing
# 2   32  108603         HR
# 3   25   82256         HR
# 4   38  119135         HR

# %% [markdown]
# Q5. Adding a Column

# %%
# Add a new column 'bonus' as 10% of salary
df['bonus'] = df['salary'] * 0.10
print(df.head())

# Add another column 'total_income' = salary + bonus
df['total_income'] = df['salary'] + df['bonus']
print(df.head())
# Out:
#    age  salary department  years_experience  is_manager    bonus
# 0   56   38392         IT              -0.8           0   3839.2
# 1   46   60535  Marketing               3.4           1   6053.5
# 2   32  108603         HR               5.0           1  10860.3
# 3   25   82256         HR               4.2           1   8225.6
# 4   38  119135         HR               4.1           1  11913.5
#    age  salary department  years_experience  is_manager    bonus  total_income
# 0   56   38392         IT              -0.8           0   3839.2       42231.2
# 1   46   60535  Marketing               3.4           1   6053.5       66588.5
# 2   32  108603         HR               5.0           1  10860.3      119463.3
# 3   25   82256         HR               4.2           1   8225.6       90481.6
# 4   38  119135         HR               4.1           1  11913.5      131048.5

# %% [markdown]
# Q6. Grouping and Aggregation

# %%
# Group by department and get average salary and experience
dept_group = df.groupby('department')[['salary', 'years_experience']].mean()
print(dept_group)

# Group by is_manager and count how many in each category
manager_group = df.groupby('is_manager')['age'].count()
print(manager_group)

# Group by department and get total salary and number of employees
summary = df.groupby('department').agg({
    'salary': ['mean', 'sum'],
    'is_manager': 'sum'
})
print(summary)
# Out:
#                   salary  years_experience
# department
# Finance     83124.708333          4.416667
# HR          73523.052632          5.089474
# IT          75825.476190          4.390476
# Marketing   77684.722222          5.205556
# is_manager
# 0    53
# 1    47
# Name: age, dtype: int64
#                   salary          is_manager
#                     mean      sum        sum
# department
# Finance     83124.708333  1994993         10
# HR          73523.052632  1396938         10
# IT          75825.476190  1592335         13
# Marketing   77684.722222  2796650         14
